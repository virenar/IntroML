# %%
from sklearn.linear_model import LinearRegression

import sklearn

# %%
sklearn.__version__
# Out:
# '0.21.2'

# %%
import pandas as pd

# %%
bmi_life_data = pd.read_csv('bmi.csv')

# %%
bmi_life_data
# Out:
#                     Country  Life expectancy       BMI
# 0               Afghanistan             52.8  20.62058
# 1                   Albania             76.8  26.44657
# 2                   Algeria             75.5  24.59620
# 3                   Andorra             84.6  27.63048
# 4                    Angola             56.7  22.25083
# 5                   Armenia             72.3  25.35542
# 6                 Australia             81.6  27.56373
# 7                   Austria             80.4  26.46741
# 8                Azerbaijan             69.2  25.65117
# 9                   Bahamas             72.2  27.24594
# 10               Bangladesh             68.3  20.39742
# 11                 Barbados             75.3  26.38439
# 12                  Belarus             70.0  26.16443
# 13                  Belgium             79.6  26.75915
# 14                   Belize             70.7  27.02255
# 15                    Benin             59.7  22.41835
# ...

# %%
import seaborn as sb

# %%
import numpy as np

# %%
sb.scatterplot(bmi_life_data['Life expectancy'], bmi_life_data['BMI'])

# %%
bmi_life_model = LinearRegression()

# %%
bmi_life_model.fit()

# %%
bmi_life_data['Life expectancy'].values.reshape(1,163)
# Out:
# array([[52.8 , 76.8 , 75.5 , 84.6 , 56.7 , 72.3 , 81.6 , 80.4 , 69.2 ,
#         72.2 , 68.3 , 75.3 , 70.  , 79.6 , 70.7 , 59.7 , 70.7 , 71.2 ,
#         77.5 , 53.2 , 73.2 , 73.2 , 58.  , 59.1 , 66.1 , 56.6 , 80.8 ,
#         70.4 , 54.3 , 78.5 , 73.4 , 76.2 , 67.1 , 57.5 , 58.8 , 79.8 ,
#         55.4 , 76.2 , 77.6 , 80.  , 78.9 , 61.8 , 74.7 , 70.2 , 73.7 ,
#         60.1 , 74.2 , 60.  , 64.9 , 79.6 , 81.1 , 75.11, 61.7 , 65.7 ,
#         71.8 , 80.  , 62.  , 80.2 , 70.3 , 70.8 , 71.2 , 57.1 , 53.6 ,
#         65.  , 61.  , 71.8 , 73.9 , 82.4 , 64.7 , 69.4 , 73.1 , 66.6 ,
#         80.1 , 80.6 , 75.1 , 82.5 , 76.9 , 67.1 , 60.8 , 77.3 , 72.4 ,
#         44.5 , 59.9 , 75.6 , 72.1 , 81.  , 74.5 , 62.2 , 52.4 , 74.5 ,
#         78.5 , 58.5 , 80.7 , 65.3 , 67.9 , 72.9 , 75.4 , 70.4 , 64.8 ,
#         76.  , 73.3 , 54.  , 59.4 , 59.1 , 68.4 , 80.3 , 77.  , 58.  ,
#         59.2 , 80.8 , 76.2 , 64.1 , 77.3 , 58.6 , 74.  , 78.2 , 69.8 ,
# ...

# %%
bmi_life_model.fit(bmi_life_data[['BMI']], bmi_life_data[['Life expectancy']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
bmi_life_model.predict(np.array(21.07931).reshape(-1,1))
# Out:
# array([[60.31564716]])
